# %% [markdown]
# # Metric Operations Module
#
# A collection of reusable computer vision utilities for image loading, geometric transformations, filtering, edge detection, and image blending.
#
# This notebook documents and demonstrates the functionality of the `image_operations` module through practical examples and visual outputs.

# %% [markdown]
# ## Contents
#
# 1. Module Overview
#
# 2. Classification operations (`classification.py`)
#     - Class Evaluator -
#         - `__init__()`
#         - `get_stats()`
#         - `get_confusion_metric()`
#         - `get_plots()`
#
# 3. Detection Operations (`detection.py`)
#
#
# 4. Segmentation Operations (`segmentation.py`)
#
#
# 5. Summary

# %% [markdown]
# ### task3 = metric_op - classification.py , detection.py, segmentation.py
#   - **Classification operations (`classification.py`)**
#     - **Class Evaluator** -
#     - `__init__()`
#     - `get_stats()`
#     - `get_confusion_metric()`
#     - `get_plots()`
#         1. __init__() :
#             * gt_json :
#                 - structure :
#                     {
#                     image_path : str,
#                     annotations : list
#                     }
#             * prediction_json :
#                 - structure :
#                     {
#                     image_path : str,
#                     predictions : list
#                     }
#
#         2. get_stats(classification_type-(binary,multiclass,multilabel))
#             - output : stats - precison,acc,recall,f1,tp,fp,fn,tn
#         3. get_confusion_metric()
#             - output : make confusion metric - plot
#         4. get_plot(num_samples)-
#             - output : plot samples in grid
#
#         **note** - everything should be stored in the object
